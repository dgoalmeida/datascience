# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import time
from datetime import datetime

### scrapping
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
my_headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS \
          X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) \
          Chrome/71.0.3578.98 Safari/537.36", \
          "Accept":"text/html,application/xhtml+xml,application/xml; \
          q=0.9,image/webp,image/apng,*/*;q=0.8"}

# %%
r = requests.get('https://www.imapi.org/perfil/osasco-sp', headers=my_headers)

# %%
content = r.content

# %%
soup = BeautifulSoup(content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="pt_br">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="pt-br" name="language"/>
# <!-- Primary Meta Tags -->
# <title>IMAPI de Osasco, SP - IMAPI</title>
# <meta content="IMAPI de Osasco, SP - IMAPI" name="title"/>
# <meta content="O IMAPI (Índice de Município Amigo da Primeira Infância) avaliou o desempenho dos 5.570 municípios brasileiros em relação à oferta de um ambiente oportuno para promoção do Desenvolvimento na Primeira Infância." name="description"/>
# <!-- Open Graph / Facebook -->
# <meta content="website" property="og:type"/>
# <meta content="https://www.imapi.org/perfil/osasco-sp" property="og:url"/>
# <meta content="IMAPI de Osasco, SP - IMAPI" property="og:title"/>
# <meta content="O IMAPI (Índice de Município Amigo da Primeira Infância) avaliou o desempenho dos 5.570 municípios brasileiros em relação à oferta de um ambiente oportuno para promoção do Desenvolvimento na Primeira Infância." property="og:description"/>
# <meta content="https://www.imapi.org/assets/images/share.png" property="og:image"/>
# <!-- Twitter -->
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="https://www.imapi.org/perfil/osasco-sp" property="twitter:url"/>
# <meta content="IMAPI de Osasco, SP - IMAPI" property="twitter:title"/>
# <meta content="O IMAPI (Índice de Município Amigo da Primeira Infância) avaliou o desempenho dos 5.570 municípios brasileiros em relação à oferta de um ambiente oportuno para promoção do Desenvolvimento na Primeira Infância." property="twitter:description"/>
# <meta content="https://www.imapi.org/assets/images/share.png" property="twitter:image"/>
# <meta content="Imapi" name="copyright"/>
# <link href="https://www.imapi.org/assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="https://www.imapi.org/assets/images/favicon.png" rel="shortcut icon"/>
# <link href="https://www.imapi.org/build/style.css?v=9" rel="stylesheet"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-168556048-1"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'UA-168556048-1');
#     </script>
# </head>
# <body>
# <header class="top-bar">
# <nav class="container-fluid wrap">
# <input class="btn-menu" role="button" type="checkbox"/>
# <ul class="nav-links">
# <li><a class="" href="https://www.imapi.org/ranking/">Ranking</a></li>
# <li><a class="" href="https://www.imapi.org/como-ler/">Como ler</a></li>
# <li><a class="" href="https://www.imapi.org/para-gestores/">Para gestores</a></li>
# <li><a class="" href="https://www.imapi.org/sobre/">Sobre o projeto</a></li>
# <li class="invisible block-sm"><a class="btn-download" href="https://www.imapi.org/download/metodologia_manual-operacional.pdf" role="button" target="_blank">Metodologia</a></li>
# <li class="lang invisible block-sm">
# <input id="lang-select" name="lang" type="checkbox"/>
# <label class="btn-lang" for="lang-select">
# <img alt="Português" src="https://www.imapi.org//assets/images/pt.svg"/>
# <span>PT</span>
# </label>
# <ul>
# <li>
# <a class="btn-lang" href="" role="button">
# <img alt="Português" src="https://www.imapi.org//assets/images/pt.svg"/>
# <span>PT</span>
# </a>
# </li>
# <li>
# <a class="btn-lang" href="https://www.imapi.org/en" role="button">
# <img alt="English" src="https://www.imapi.org//assets/images/en.svg"/>
# <span>EN</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="invisible block-sm"><a href="mailto:contato@imapi.org">contato@imapi.org</a></li>
# </ul>
# <div class="logo-wrapper">
# <a class="logo" href="https://www.imapi.org/"></a>
# </div>
# <ul class="nav-btns">
# <li>
# <input class="buscar" id="inputmunicipios" list="municipios" name="municipios" placeholder="Buscar município"/>
# <datalist id="municipios"> </datalist>
# </li>
# <li class="invisible-sm">
# <a class="btn-download" href="https://www.imapi.org/download/metodologia_manual-operacional.pdf" role="button" target="_blank">Metodologia</a>
# </li>
# <li class="lang invisible-sm">
# <input id="lang-select" name="lang" type="checkbox"/>
# <label class="btn-lang" for="lang-select">
# <img alt="Português" src="https://www.imapi.org//assets/images/pt.svg"/>
# <span>PT</span>
# </label>
# <ul>
# <li>
# <a class="btn-lang" href="" role="button">
# <img alt="Português" src="https://www.imapi.org//assets/images/pt.svg"/>
# <span>PT</span>
# </a>
# </li>
# <li>
# <a class="btn-lang" href="https://www.imapi.org/en" role="button">
# <img alt="English" src="https://www.imapi.org//assets/images/en.svg"/>
# <span>EN</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="social invisible-sm">
# <input name="social" type="checkbox"/>
# <ul>
# <li><a class="btn-social facebook" href="http://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.imapi.org%2Fperfil%2Fosasco-sp&amp;t=IMAPI+de+Osasco%2C+SP+-+Imapi" role="button" target="_blank"></a></li>
# <li><a class="btn-social twitter" href="https://twitter.com/intent/tweet?text=IMAPI+de+Osasco%2C+SP+-+Imapi&amp;url=https%3A%2F%2Fwww.imapi.org%2Fperfil%2Fosasco-sp" role="button" target="_blank"></a></li>
# <li><a class="btn-social linkedin" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https%3A%2F%2Fwww.imapi.org%2Fperfil%2Fosasco-sp&amp;title=IMAPI+de+Osasco%2C+SP+-+Imapi&amp;source=LinkedIn" role="button" target="_blank"></a></li>
# </ul>
# </li>
# </ul>
# </nav>
# </header>
# <!-- Conteúdo -->
# <main>
# <!-- Dimensões -->
# <div class="container-fluid wrap mt3">
# <div class="row top-xs">
# <!-- Esquerda -->
# <article class="col-xs-12 col-md-6 dimensao-sticky">
# <h1 class="t5 tcr w800 mb05 tc tl-md">Osasco, SP</h1>
# <!-- Cabeçalho -->
# <section class="row tc tl-md">
# <div class="col-xs-3">
# <p class="dado"><strong>Sudeste</strong></p>
# <p class="label">Região</p>
# </div>
# <div class="col-xs-3">
# <p class="dado"><strong>Grande porte</strong></p>
# <p class="label">Porte da cidade</p>
# </div>
# <div class="col-xs-3">
# <p class="dado"><strong>696.382</strong></p>
# <p class="label">Habitantes</p>
# </div>
# <div class="col-xs-3">
# <p class="dado"><strong>10.320</strong></p>
# <p class="label">Nascimentos ao ano/ 1000 habitantes</p>
# </div>
# </section>
# <!-- Gráfico -->
# <section class="row center-xs">
# <div class="col-xs">
# <div class="petalas">
# <svg viewbox="0 0 450 257">
# <g class="saude" data-desempenho="baixo" data-nota="46" data-titulo="saúde" data-tooltip="saude">
# <path class="petala psbaixo" d="M224.6,255.7s-41.2-48.4-41.2-108.2c0-49.2,27.9-90.7,37.8-103.8a4.3,4.3,0,0,1,6.9,0c9.9,13.2,37.8,54.7,37.8,103.8C265.8,207.2,224.6,255.7,224.6,255.7Z"></path>
# <circle class="nota" cx="224.2" cy="18" r="15"></circle>
# <text x="224" y="22">46</text>
# <g class="guia">
# <line x1="224.5" x2="224.5" y1="253.8" y2="41.6"></line>
# <circle cx="224.3" cy="146.2" r="2.2"></circle>
# <circle cx="224.3" cy="42.3" r="2.2"></circle>
# <circle cx="224.3" cy="94.2" r="2.2"></circle>
# </g>
# </g>
# <g class="nutricao" data-desempenho="alto" data-nota="45" data-titulo="nutrição" data-tooltip="nutricao">
# <path class="petala psalto" d="M224.6,255.7s-41.2-48.4-41.2-108.2c0-49.2,27.9-90.7,37.8-103.8a4.3,4.3,0,0,1,6.9,0c9.9,13.2,37.8,54.7,37.8,103.8C265.8,207.2,224.6,255.7,224.6,255.7Z"></path>
# <circle class="nota" cx="224.2" cy="18" r="15"></circle>
# <text x="224" y="22">45</text>
# <g class="guia">
# <line x1="224.5" x2="224.5" y1="253.8" y2="41.6"></line>
# <circle cx="224.3" cy="146.2" r="2.2"></circle>
# <circle cx="224.3" cy="42.3" r="2.2"></circle>
# <circle cx="224.3" cy="94.2" r="2.2"></circle>
# </g>
# </g>
# <g class="cuidado" data-desempenho="baixo" data-nota="0" data-titulo="cuidado responsivo" data-tooltip="cuidado">
# <path class="petala psbaixo" d="M224.6,255.7s-41.2-48.4-41.2-108.2c0-49.2,27.9-90.7,37.8-103.8a4.3,4.3,0,0,1,6.9,0c9.9,13.2,37.8,54.7,37.8,103.8C265.8,207.2,224.6,255.7,224.6,255.7Z"></path>
# <circle class="nota" cx="224.2" cy="18" r="15"></circle>
# <text x="224" y="22">0</text>
# <g class="guia">
# <line x1="224.5" x2="224.5" y1="253.8" y2="41.6"></line>
# <circle cx="224.3" cy="146.2" r="2.2"></circle>
# <circle cx="224.3" cy="42.3" r="2.2"></circle>
# <circle cx="224.3" cy="94.2" r="2.2"></circle>
# </g>
# </g>
# <g class="aprendizagem" data-desempenho="médio" data-nota="74" data-titulo="aprendizagem inicial" data-tooltip="aprendizagem">
# <path class="petala psmédio" d="M224.6,255.7s-41.2-48.4-41.2-108.2c0-49.2,27.9-90.7,37.8-103.8a4.3,4.3,0,0,1,6.9,0c9.9,13.2,37.8,54.7,37.8,103.8C265.8,207.2,224.6,255.7,224.6,255.7Z"></path>
# <circle class="nota" cx="224.2" cy="18" r="15"></circle>
# <text x="224" y="22">74</text>
# <g class="guia">
# <line x1="224.5" x2="224.5" y1="253.8" y2="41.6"></line>
# <circle cx="224.3" cy="146.2" r="2.2"></circle>
# <circle cx="224.3" cy="42.3" r="2.2"></circle>
# <circle cx="224.3" cy="94.2" r="2.2"></circle>
# </g>
# </g>
# <g class="seguranca" data-desempenho="baixo" data-nota="13" data-titulo="segurança e proteção" data-tooltip="seguranca">
# <path class="petala psbaixo" d="M224.6,255.7s-41.2-48.4-41.2-108.2c0-49.2,27.9-90.7,37.8-103.8a4.3,4.3,0,0,1,6.9,0c9.9,13.2,37.8,54.7,37.8,103.8C265.8,207.2,224.6,255.7,224.6,255.7Z"></path>
# <circle class="nota" cx="224.2" cy="18" r="15"></circle>
# <text x="224" y="22">13</text>
# <g class="guia">
# <line x1="224.5" x2="224.5" y1="253.8" y2="41.6"></line>
# <circle cx="224.3" cy="146.2" r="2.2"></circle>
# <circle cx="224.3" cy="42.3" r="2.2"></circle>
# <circle cx="224.3" cy="94.2" r="2.2"></circle>
# </g>
# </g>
# </svg>
# </div>
# </div>
# </section>
# <!-- Posição e nota -->
# <section class="row bottom-xs">
# <div class="col-xs-4 tl">
# <p class="dado"><strong>2.619º <span class="invisible-sm">lugar</span></strong> de 5.570</p>
# <p class="label">Ranking Brasil</p>
# </div>
# <div class="col-xs-4 tc">
# <p class="t6 tcr ff2 w900">44</p>
# <p class="label">IMAPI médio</p>
# </div>
# <div class="col-xs-4 tr">
# <p class="dado"><strong>300º <span class="invisible-sm">lugar</span></strong> de 645</p>
# <p class="label">Ranking estadual</p>
# </div>
# </section>
# <!-- Comparativo Geral -->
# <section>
# <div class="row">
# <div class="col-xs-12">
# <article class="comparativo geral">
# <section class="grafico">
# <div class="guia">
# <div class="baixo" style="left:41%"></div>
# <div class="medio" style="left:47%"></div>
# <div class="alto" style="left:100%"></div>
# <div class="min"></div>
# <div class="max"></div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-desempenho="médio" data-local="municipio" data-nota="44" data-titulo="Osasco, SP" data-tooltip="imapi" style="left: 44.40%"></div>
# <div class="local" data-desempenho="médio" data-local="capital" data-nota="46" data-titulo="São Paulo, SP" data-tooltip="imapi" style="left: 45.85%"></div>
# <div class="local" data-desempenho="médio" data-estado="SP" data-local="estado" data-nota="45" data-titulo="São Paulo" data-tooltip="imapi" style="left: 45.00%"></div>
# <div class="local" data-desempenho="médio" data-local="pais" data-nota="44" data-titulo="Brasil" data-tooltip="imapi" style="left: 44.00%"></div>
# </div>
# <div class="nota" style="width: calc(44.40% + 30px);"></div>
# </section>
# <section class="legenda">
# <p class="desc">Comparação com as médias do estado e  Brasil</p>
# <div class="componente">
# <div class="local" data-desempenho="médio" data-local="capital" data-nota="46" data-titulo="São Paulo, SP" data-tooltip="imapi"></div>
# <div>
# <p class="dado"><strong>46</strong> PTS</p>
# <p class="label">IMAPI Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-desempenho="médio" data-estado="SP" data-local="estado" data-nota="45" data-titulo="São Paulo" data-tooltip="imapi"></div>
# <div>
# <p class="dado"><strong>45</strong> PTS</p>
# <p class="label">IMAPI Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-desempenho="médio" data-local="pais" data-nota="44" data-titulo="Brasil" data-tooltip="imapi"></div>
# <div>
# <p class="dado"><strong>44</strong> PTS</p>
# <p class="label">IMAPI Brasil</p>
# </div>
# </div>
# </section>
# </article>
# </div>
# </div>
# </section>
# <!-- Outras informações -->
# <section>
# <div class="row">
# <div class="col-xs-12 tc">
# <label class="btn-expandir" for="outras-informacoes">Ver mais sobre o município</label>
# <input class="hidden" id="outras-informacoes" type="checkbox"/>
# <div class="card card-roxo outras-informacoes">
# <p class="t4 w700 pr2">Outras informações sobre Osasco, SP</p>
# <label class="btn-fechar" for="outras-informacoes"></label>
# <div class="row">
# <div class="col-xs-6 col-md-4">
# <p class="t1 w700 uc mb1 ls1 mt2">Menores de 5 anos</p>
# <div class="mb1">
# <p class="dado"><strong>6,70%</strong> (46.542)</p>
# <p class="label">da população total</p>
# </div>
# <div>
# <p class="dado"><strong>25,38%</strong> (11.814)</p>
# <p class="label">em vulnerabilidade</p>
# </div>
# </div>
# <div class="col-xs-6 col-md-4">
# <p class="t1 w700 uc mb1 ls1 mt2">Serviços de suporte</p>
# <div class="mb1 positivo">
# <p class="dado"><strong>Sim</strong></p>
# <p class="label">Hospital Amigo da Criança</p>
# </div>
# <div class="positivo">
# <p class="dado"><strong> Sim</strong></p>
# <p class="label">Banco de leite humano</p>
# </div>
# </div>
# <div class="col-xs-12 col-md-4">
# <p class="t1 w700 uc mb1 ls1 mt2">Saneamento</p>
# <div class="mb1">
# <div class="flex middle-xs">
# <p class="dado"><strong>100% </strong></p>
# <div class="barra ml05"><div style="width:100%"></div></div>
# </div>
# <p class="label">Abastecimento de água</p>
# </div>
# <div>
# <div class="flex middle-xs">
# <p class="dado"><strong>85,28%</strong></p>
# <div class="barra ml05"><div style="width:85%"></div></div>
# </div>
# <p class="label">Esgotamento sanitário</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </article>
# <!-- Direita -->
# <article class="col-xs-12 col-md-6 mt3-md">
# <p class="t2 tcr w400 mb1 pl2-md pr2-md">Conheça o desempenho do seu município nos cinco domínios do <strong>modelo de Nutrição de Cuidados e seus indicadores que compõe o IMAPI</strong></p>
# <div>
# <!-- Card -->
# <section class="card" data-dimensao="saude">
# <!-- Comparativo principal -->
# <article class="comparativo">
# <section class="info">
# <p class="titulo">saúde </p>
# <div class="notas">
# <p><strong>baixo</strong>Desempenho</p>
# <p><strong>46</strong>Pontos</p>
# </div>
# <div class="posicoes">
# <div>
# <p class="dado"><strong>4.794º lugar</strong> de 5.570</p>
# <p class="label">ranking brasil</p>
# </div>
# <div>
# <p class="dado"><strong>583º lugar</strong> de 645</p>
# <p class="label">ranking estadual</p>
# </div>
# </div>
# </section>
# <section class="grafico">
# <div class="guia">
# <div class="baixo" style="left:33.333%"></div>
# <div class="medio" style="left:66.666%"></div>
# <div class="alto" style="left:100%"></div>
# <div class="min"></div>
# <div class="max"></div>
# </div>
# <div class="folhas">
# <div class="baixo" style="width:33.333%"></div>
# <div class="medio" style="width:66.666%"></div>
# <div class="alto" style="width:100%"></div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-desempenho="baixo" data-local="municipio" data-nota="46" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 33%"></div>
# <div class="local" data-desempenho="médio" data-local="capital" data-nota="57" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 67%"></div>
# <div class="local" data-desempenho="médio" data-estado="SP" data-local="estado" data-nota="59" data-titulo="São Paulo" data-tooltip="saude" style="left:  67%"></div>
# <div class="local" data-desempenho="médio" data-local="pais" data-nota="58" data-titulo="Brasil" data-tooltip="saude" style="left: 67%"></div>
# </div>
# <div class="nota" style="width: 33%"></div>
# </section>
# <section class="legenda">
# <p class="desc">Comparação com as médias do estado e  Brasil</p>
# <div class="componente">
# <div class="local" data-desempenho="médio" data-local="capital" data-nota="57" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>57</strong> PTS</p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-desempenho="médio" data-estado="SP" data-local="estado" data-nota="59" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>59</strong> PTS</p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-desempenho="médio" data-local="pais" data-nota="58" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>58</strong> PTS</p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Botão Expandir -->
# <input id="check-saude" name="expandir-card" type="checkbox"/>
# <label class="btn-expandir" for="check-saude">Ver composição</label>
# <!-- Indicadores -->
# <div class="complementar">
# <p class="titulo-complementar">Indicadores relacionados à saúde</p>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Início adequado do pré-natal</strong></p>
# <p class="label">Percentual de gestantes que iniciaram o pré-natal com 12 semanas ou menos</p>
# <div class="informativo" data-calculo="(Total de gestantes que iniciaram o pré-natal com 12 semanas ou menos / total de gestantes acompanhadas) * 100, por ano e município de residência." data-importancia="O início precoce do pré-natal favorece o rastreamento de situações de risco e a possibilidade de realizar o tratamento de possíveis intercorrências de forma precoce, promovendo a saúde e o adequado desenvolvimento fetal." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="85,63" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 85.63%"></div>
# <div class="local" data-local="capital" data-nota="85,24" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 85.24%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="85,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 85.00%"></div>
# <div class="local" data-local="pais" data-nota="81,00" data-titulo="Brasil" data-tooltip="saude" style="left: 81.00%"></div>
# </div>
# <div class="nota" style="width: calc(85.63% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="85,63" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>85,63</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="85,24" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>85,24</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="85,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>85,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="81,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>81,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Consultas de pré-natal</strong></p>
# <p class="label">Percentual de gestantes com 6 ou mais consultas de pré‐natal </p>
# <div class="informativo" data-calculo="(Número de mulheres com 6 ou mais consultas de pré-natal / total de nascidos vivos) *100, por ano e município de residência." data-importancia="O período pré-natal é um período sensível na formação e desenvolvimento do bebê. A realização adequada do pré-natal, a prevenção e o diagnóstico precoce de intercorrências podem afetar o desenvolvimento infantil além de promover e proteger a saúde da mãe e do bebê." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="75,62" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 75.62%"></div>
# <div class="local" data-local="capital" data-nota="86,22" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 86.22%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="88,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 88.00%"></div>
# <div class="local" data-local="pais" data-nota="81,00" data-titulo="Brasil" data-tooltip="saude" style="left: 81.00%"></div>
# </div>
# <div class="nota" style="width: calc(75.62% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="75,62" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>75,62</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="86,22" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>86,22</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="88,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>88,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="81,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>81,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Gravidez na adolescência</strong></p>
# <p class="label">Percentual  de gravidez na adolescência</p>
# <div class="informativo" data-calculo="(Número de nascidos vivos de mães com idade de 10 a 19 anos / total de nascidos vivos) * 100, por ano e município de residência." data-importancia="A gravidez na adolescência é uma situação de risco à saúde da adolescente e do recém-nascido, com maior risco de retardo de crescimento intra-uterino e atrasos no desenvolvimento." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="13,38" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 13.38%"></div>
# <div class="local" data-local="capital" data-nota="12,18" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 12.18%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="16,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 16.00%"></div>
# <div class="local" data-local="pais" data-nota="20,00" data-titulo="Brasil" data-tooltip="saude" style="left: 20.00%"></div>
# </div>
# <div class="nota" style="width: calc(13.38% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="13,38" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>13,38</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="12,18" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>12,18</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="16,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>16,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="20,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>20,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Cesáreas</strong></p>
# <p class="label">Percentual de cesáreas</p>
# <div class="informativo" data-calculo="(Total de nascidos vivos via cesárea / total de nascidos vivos) * 100, por ano e município de residência." data-importancia="Altas taxas de cesáreas eletivas estão associadas à prematuridade e à maior morbimortalidade materna e infantil." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="56,61" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 56.61%"></div>
# <div class="local" data-local="capital" data-nota="52,25" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 52.25%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="69,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 69.00%"></div>
# <div class="local" data-local="pais" data-nota="58,00" data-titulo="Brasil" data-tooltip="saude" style="left: 58.00%"></div>
# </div>
# <div class="nota" style="width: calc(56.61% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="56,61" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>56,61</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="52,25" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>52,25</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="69,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>69,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="58,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>58,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Prematuridade</strong></p>
# <p class="label">Percentual de crianças nascidas com menos de 37 semanas completas de gestação</p>
# <div class="informativo" data-calculo="(Total de crianças nascidas com menos de 37 semanas completas de gestação / total de nascidos vivos) * 100, por ano e município de residência." data-importancia="O nascimento prematuro é um fator de risco para o inadequado desenvolvimento infantil nos primeiros anos além de ser um indicador de um pré-natal deficiente." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="13,30" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 13.30%"></div>
# <div class="local" data-local="capital" data-nota="10,62" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 10.62%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="12,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 12.00%"></div>
# <div class="local" data-local="pais" data-nota="11,00" data-titulo="Brasil" data-tooltip="saude" style="left: 11.00%"></div>
# </div>
# <div class="nota" style="width: calc(13.30% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="13,30" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>13,30</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="10,62" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>10,62</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="12,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>12,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="11,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>11,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Baixo peso ao nascer</strong></p>
# <p class="label">Percentual de nascidos vivos com menos de 2500g</p>
# <div class="informativo" data-calculo="(Total de nascidos vivos com peso menor que 2500g / total de nascidos vivos) * 100, por ano e município de residência." data-importancia="O baixo peso ao nascer é um fator de risco para o inadequado desenvolvimento infantil, gerando efeitos negativos no desenvolvimento mental, motor e no crescimento. É também um indicador de pré-natal deficiente, desnutrição materna, gestação na adolescência e infecções não tratadas." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="9,62" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 9.62%"></div>
# <div class="local" data-local="capital" data-nota="9,51" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 9.51%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="9,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 9.00%"></div>
# <div class="local" data-local="pais" data-nota="8,00" data-titulo="Brasil" data-tooltip="saude" style="left: 8.00%"></div>
# </div>
# <div class="nota" style="width: calc(9.62% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="9,62" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>9,62</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="9,51" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>9,51</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="9,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>9,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="8,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>8,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Sífilis Congênita</strong></p>
# <p class="label">Casos confirmados e notificados de sífilis congênita para cada 10.000 crianças  menores de 5 anos</p>
# <div class="informativo" data-calculo="(Número de casos confirmados e notificados de sífilis congênita em menores de 5 anos / população de menores de 5 anos) * 10.000, por ano e por município de residência." data-importancia="A sífilis congênita pode ocasionar graves alterações no desenvolvimento da criança, incluindo pseudoparalisia dos membros, surdez neurológica e dificuldade no aprendizado." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="14,40" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 14.40%"></div>
# <div class="local" data-local="capital" data-nota="13,87" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 13.87%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="9,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 9.00%"></div>
# <div class="local" data-local="pais" data-nota="7,00" data-titulo="Brasil" data-tooltip="saude" style="left: 7.00%"></div>
# </div>
# <div class="nota" style="width: calc(14.40% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="14,40" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>14,40</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="13,87" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>13,87</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="9,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>9,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="7,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>7,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Visitas domiciliares nos primeiros 10 dias de vida</strong></p>
# <p class="label">Percentual de equipes da atenção básica que participaram do PMAQ 2º ciclo e fizeram visitas domiciliares nos primeiros 10 dias de vida </p>
# <div class="informativo" data-calculo="(Número de equipes que fizeram a visita domiciliar nos 10 primeiros dias de vida / total de equipes que participaram do PMAQ 2° ciclo) * 100, por ano e município de residência" data-importancia="Visitas domiciliares da equipe de saúde nos primeiros dez dias pós-parto ajudam a detectar, prevenir e tratar oportunamente intercorrências no pós-parto e na amamentação (nutrição adequada). As visitas domiciliares das equipes de saúde também refletem o acesso e vínculo da mãe e do recém-nascido com o serviço de saúde." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="40,00" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 40.00%"></div>
# <div class="local" data-local="capital" data-nota="97,55" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 97.55%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="73,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 73.00%"></div>
# <div class="local" data-local="pais" data-nota="81,00" data-titulo="Brasil" data-tooltip="saude" style="left: 81.00%"></div>
# </div>
# <div class="nota" style="width: calc(40.00% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="40,00" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>40,00</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="97,55" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>97,55</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="73,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>73,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="81,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>81,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Cobertura de imunização</strong></p>
# <p class="label">Percentual de crianças que receberam o primeiro reforço da DTP</p>
# <div class="informativo" data-calculo="(número de doses do 1º reforço da vacina DTP (tríplice bacteriana) / população alvo) * 100, por ano e município de residência." data-importancia="Uma boa cobertura vacinal garante a manutenção de baixas incidências dos agravos imunopreviníveis que podem influenciar o desenvolvimento infantil." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="76,79" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 76.79%"></div>
# <div class="local" data-local="capital" data-nota="47,51" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 47.51%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="71,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 71.00%"></div>
# <div class="local" data-local="pais" data-nota="73,00" data-titulo="Brasil" data-tooltip="saude" style="left: 73.00%"></div>
# </div>
# <div class="nota" style="width: calc(76.79% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="76,79" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>76,79</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="47,51" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>47,51</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="71,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>71,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="73,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>73,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Cobertura da Atenção Básica de Saúde</strong></p>
# <p class="label">Percentual da população coberta pela Atenção Básica</p>
# <div class="informativo" data-calculo="[número de equipes de Saúde da Família * 3.450 + (número de equipes de Atenção Básica parametrizadas + número de equipes de Saúde da Família equivalentes) ∗ 3.000] no Mês de referência (dezembro)/ Estimativa populacional * 100." data-importancia="A cobertura populacional de equipes de Atenção Básica reflete o acesso aos serviços de saúde. A Atenção Básica é responsável por diversas ações de prevenção e promoção do adequado desenvolvimento infantil e diagnóstico precoce de intercorrências." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="48,00" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 48.00%"></div>
# <div class="local" data-local="capital" data-nota="60,82" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 60.82%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="80,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 80.00%"></div>
# <div class="local" data-local="pais" data-nota="92,00" data-titulo="Brasil" data-tooltip="saude" style="left: 92.00%"></div>
# </div>
# <div class="nota" style="width: calc(48.00% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="48,00" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>48,00</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="60,82" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>60,82</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="80,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>80,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="92,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>92,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Internação por pneumonia ou gastroenterites</strong></p>
# <p class="label">Percentual  de internações de crianças menores de 5 anos por pneumonia ou gastroenterites</p>
# <div class="informativo" data-calculo="(Total de internações de crianças menores de 5 anos com pneumonia ou gastroenterite / total de crianças menores de 5 anos) * 100, por ano e município de residência." data-importancia="Gastroenterites e doenças respiratórias agudas são resultados de um conjunto de variáveis biológicas, ambientais e socioculturais e indicam um alto grau de vulnerabilidade, podendo ocasionar maiores riscos e comprometimentos para o desenvolvimento infantil. São condições que poderiam ser evitadas ou reduzidas por ações efetivas de atenção primária (prevenção, diagnóstico e tratamento precoce)." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="0,23" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 0.23%"></div>
# <div class="local" data-local="capital" data-nota="0,33" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 0.33%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="0,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 0.00%"></div>
# <div class="local" data-local="pais" data-nota="1,00" data-titulo="Brasil" data-tooltip="saude" style="left: 1.00%"></div>
# </div>
# <div class="nota" style="width: calc(0.23% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="0,23" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>0,23</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="0,33" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>0,33</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="0,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>0,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="1,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>1,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Mortalidade materna</strong></p>
# <p class="label">Mortes de mulheres por causas relacionadas à gravidez, parto ou puerpério para cada 100.000 nascidos vivos </p>
# <div class="informativo" data-calculo="(Número de óbitos de mulheres, por causas ligadas a gravidez, parto e puerpério / número de nascidos vivos) * 100.000, por ano e município de residência." data-importancia="A morte materna pode aumentar os riscos de mortalidade infantil, morbidade e atraso de desenvolvimento na primeira infância." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">10.000,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="77,54" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 0.78%"></div>
# <div class="local" data-local="capital" data-nota="41,84" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 0.42%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="61,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 0.61%"></div>
# <div class="local" data-local="pais" data-nota="71,00" data-titulo="Brasil" data-tooltip="saude" style="left: 0.71%"></div>
# </div>
# <div class="nota" style="width: calc(0.78% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="77,54" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>77,54</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="41,84" data-titulo="São Paulo, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>41,84</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="61,00" data-titulo="São Paulo" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>61,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="71,00" data-titulo="Brasil" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>71,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Mortalidade na Infância</strong></p>
# <p class="label">Óbitos de crianças menores de 5 anos para 1000 nascidos vivos</p>
# <div class="informativo" data-calculo="(Número de óbitos entre crianças menores de 5 anos / total de nascidos vivos) * 1.000, por ano e município de residência." data-importancia="A maior parte dos óbitos na infância concentra-se no primeiro ano de vida, com elevada participação de causas perinatais (fatores ligados à gestação, ao parto e ao pós-parto), em geral preveníveis. Após o primeiro ano de vida, a mortalidade está associada com a exposição a fatores ambientais como, por exemplo, falta de acesso a saúde de qualidade e outros estressores ambientais relacionados à pobreza. Além disso, esse indicador expressa a falha em diversas políticas públicas na promoção da saúde e pleno desenvolvimento infantil." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">100,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="14,64" data-titulo="Osasco, SP" data-tooltip="saude" style="left: 14.64%"></div>
# <div class="local" data-local="capital" data-nota="14,85" data-titulo="São Paulo, SP" data-tooltip="saude" style="left: 14.85%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="13,00" data-titulo="São Paulo" data-tooltip="saude" style="left: 13.00%"></div>
# <div class="local" data-local="pais" data-nota="16,00" data-titulo="Brasil" data-tooltip="saude" style="left: 16.00%"></div>
# </div>
# <div class="nota" style="width: calc(14.64% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="14,64" data-titulo="Osasco, SP" data-tooltip="saude"></div>
# <div>
# <p class="dado"><strong>14,64</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# ...
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">20,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="15,93" data-titulo="Osasco, SP" data-tooltip="seguranca" style="left: 79.65%"></div>
# <div class="local" data-local="capital" data-nota="15,57" data-titulo="São Paulo, SP" data-tooltip="seguranca" style="left: 77.85%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="12,00" data-titulo="São Paulo" data-tooltip="seguranca" style="left: 60.00%"></div>
# <div class="local" data-local="pais" data-nota="6,00" data-titulo="Brasil" data-tooltip="seguranca" style="left: 30.00%"></div>
# </div>
# <div class="nota" style="width: calc(79.65% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="15,93" data-titulo="Osasco, SP" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>15,93</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="15,57" data-titulo="São Paulo, SP" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>15,57</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="12,00" data-titulo="São Paulo" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>12,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="6,00" data-titulo="Brasil" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>6,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# <!-- Indicador -->
# <article class="comparativo indicador">
# <header>
# <p class="dado"><strong>Homicídios</strong></p>
# <p class="label">Taxa de homicídio estimada por  100 mil habitantes </p>
# <div class="informativo" data-calculo="(∑ Número de óbitos por agressão, número de óbitos ocasionados por intervenção legal, número de homicídios ocultos / população municipal) * 100.000, por ano e município." data-importancia="A exposição precoce à ambientes violentos pode prejudicar o desenvolvimento infantil, incluindo o desenvolvimento cerebral e produzir danos em outras partes do sistema nervoso com consequências ao longo de toda a vida. Um ambiente seguro com baixos índices de violência permite que a criança e seus cuidadores estejam seguros e protegidos, livres para ir e vir, permitindo a exploração do meio ambiente ao seu redor." data-tooltip="informativo"></div>
# </header>
# <section class="grafico">
# <div class="guia">
# <div class="min">0,00</div>
# <div class="max">250,00</div>
# </div>
# <div class="marcadores">
# <div class="local ativo" data-local="municipio" data-nota="18,80" data-titulo="Osasco, SP" data-tooltip="seguranca" style="left: 7.52%"></div>
# <div class="local" data-local="capital" data-nota="13,20" data-titulo="São Paulo, SP" data-tooltip="seguranca" style="left: 5.28%"></div>
# <div class="local" data-estado="SP" data-local="estado" data-nota="12,00" data-titulo="São Paulo" data-tooltip="seguranca" style="left: 4.80%"></div>
# <div class="local" data-local="pais" data-nota="26,00" data-titulo="Brasil" data-tooltip="seguranca" style="left: 10.40%"></div>
# </div>
# <div class="nota" style="width: calc(7.52% + 30px);"></div>
# </section>
# <section class="legenda">
# <div class="componente">
# <div class="local ativo" data-local="municipio" data-nota="18,80" data-titulo="Osasco, SP" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>18,80</strong></p>
# <p class="label">Município</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="capital" data-nota="13,20" data-titulo="São Paulo, SP" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>13,20</strong></p>
# <p class="label">Capital</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-estado="SP" data-local="estado" data-nota="12,00" data-titulo="São Paulo" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>12,00</strong></p>
# <p class="label">Estado</p>
# </div>
# </div>
# <div class="componente">
# <div class="local" data-local="pais" data-nota="26,00" data-titulo="Brasil" data-tooltip="seguranca"></div>
# <div>
# <p class="dado"><strong>26,00</strong></p>
# <p class="label">Brasil</p>
# </div>
# </div>
# </section>
# </article>
# </div>
# </section>
# </div>
# </article>
# </div>
# </div>
# <!-- Quadros -->
# <div class="container-fluid wrap mt2">
# <div class="row">
# <div class="col-xs-12 col-md-6">
# <div class="card card-ranking">
# <p class="t4 w400 tcr mb2"><strong>Veja o ranking do seu estado</strong> ou região. Você pode ordenar pelo IMAPI geral ou qualquer um dos 5 domínios.</p>
# <a class="btn" href="https://www.imapi.org/ranking/SP">Ver ranking de São Paulo</a>
# </div>
# </div>
# <div class="col-xs-12 col-md-6">
# <div class="card card-buscar">
# <p class="t4 w400 tcr mb2"><strong>Busque por um dos 5.570 municípios</strong> brasileiros e veja o perfil completo.</p>
# <a class="btn-buscar" onclick="document.getElementById('inputmunicipios').focus()">Buscar município</a>
# </div>
# </div>
# </div>
# </div>
# </main>
# <!-- Footer -->
# <footer>
# <article>
# <div class="container-fluid wrap">
# <div class="row between-xs">
# <div class="col-xs-12 col-md-6">
# <div class="flex">
# <a class="logo" href="https://www.imapi.org//"></a>
# <div>
# <p class="t2 w400 tcb mb1">O IMAPI foi criado com base em um conjunto de indicadores dos cinco domínios do modelo conceitual de Nutrição de Cuidados (Nurturing Care): Saúde, Nutrição, Cuidado Responsivo, Aprendizado Precoce e Segurança e Proteção. O IMAPI avaliou o desempenho dos 5.570 municípios brasileiros em relação à oferta de um ambiente oportuno para promoção do Desenvolvimento na Primeira Infância.</p>
# <p class="t2 w400 tcb uc mb2" uc=""><a class="link" href="mailto:contato@imapi.org">contato@imapi.org</a></p>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-md-5">
# <nav class="row">
# <div class="col-xs-3">
# <ul class="mb0 t1 uc lh1 tcb ls1">
# <li><p class="w800 block mb1">Rankings</p></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/ranking/municipios/">Municípios</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/ranking/capitais/">Capitais</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/ranking/estados/">Estados</a></li>
# </ul>
# </div>
# <div class="col-xs-3">
# <ul class="mb0 t1 uc lh1 tcb ls1">
# <li><p class="w800 block mb1">Para Gestores</p></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/para-gestores/#importancia">Importância</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/para-gestores/#faq">Faq</a></li>
# </ul>
# </div>
# <div class="col-xs-3">
# <ul class="mb0 t1 uc lh1 tcb ls1">
# <li><p class="w800 block mb1">Sobre o Projeto</p></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/sobre/#o-que-e">O que é o IMAPI</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/sobre/#dominios">Domínios</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/sobre/#indicadores">Indicadores</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/sobre/#etapas">Etapas</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/sobre/#equipe">Equipe</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/sobre/#downloads">Downloads</a></li>
# </ul>
# </div>
# <div class="col-xs-3">
# <ul class="mb0 t1 uc lh1 tcb ls1">
# <li><p class="w800 block mb1">Como Ler</p></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/como-ler/#dominios">Domínios</a></li>
# <li><a class="w400 block mb05 link" href="https://www.imapi.org/como-ler/#indicadores">Indicadores</a></li>
# </ul>
# </div>
# </nav>
# </div>
# </div>
# </div>
# </article>
# <article class="bottom-bar">
# <div class="container-fluid wrap">
# <div class="row between-xs center-xs">
# <div class="col-xs-4 middle-xs start-xs">
# <p class="t1 w400 tcb uc ff2 tcb">© 2020 IMAPI</p>
# </div>
# <div class="col-xs-8 middle-xs end-xs">
# <p class="t1 w400 tcb uc ff2 tcb">Desenvolvido por <a class="w800 link" href="https://odd.studio/" target="_blank">ODD.GROUP</a> e <a class="link w800" href="http://cafe.art.br/" target="_blank">Cafe.art.br</a></p>
# </div>
# </div>
# </div>
# </article>
# </footer>
# <aside class="tooltip"></aside>
# <aside class="svg-degrade">
# <svg>
# <defs>
# <radialgradient cx="-1246.94" cy="-110.96" gradienttransform="translate(103035.5 25775.7) scale(82.45 230.64)" gradientunits="userSpaceOnUse" id="gradiente_saude" r="0.4">
# <stop offset="0" stop-color="#C49543" stop-opacity="0.3"></stop>
# <stop offset="1" stop-color="#C49543" stop-opacity="0.95"></stop>
# </radialgradient>
# <radialgradient cx="-1246.94" cy="-110.96" gradienttransform="translate(103035.5 25775.7) scale(82.45 230.64)" gradientunits="userSpaceOnUse" id="gradiente_nutricao" r="0.4">
# <stop offset="0" stop-color="#E25F8F" stop-opacity="0.3"></stop>
# <stop offset="1" stop-color="#E25F8F" stop-opacity="0.95"></stop>
# </radialgradient>
# <radialgradient cx="-1246.94" cy="-110.96" gradienttransform="translate(103035.5 25775.7) scale(82.45 230.64)" gradientunits="userSpaceOnUse" id="gradiente_cuidado" r="0.4">
# <stop offset="0" stop-color="#00A38A" stop-opacity="0.3"></stop>
# <stop offset="1" stop-color="#00A38A" stop-opacity="0.95"></stop>
# </radialgradient>
# <radialgradient cx="-1246.94" cy="-110.96" gradienttransform="translate(103035.5 25775.7) scale(82.45 230.64)" gradientunits="userSpaceOnUse" id="gradiente_aprendizagem" r="0.4">
# <stop offset="0" stop-color="#E36959" stop-opacity="0.3"></stop>
# <stop offset="1" stop-color="#E36959" stop-opacity="0.95"></stop>
# </radialgradient>
# <radialgradient cx="-1246.94" cy="-110.96" gradienttransform="translate(103035.5 25775.7) scale(82.45 230.64)" gradientunits="userSpaceOnUse" id="gradiente_seguranca" r="0.4">
# <stop offset="0" stop-color="#027999" stop-opacity="0.3"></stop>
# <stop offset="1" stop-color="#027999" stop-opacity="0.95"></stop>
# </radialgradient>
# </defs>
# </svg>
# </aside>
# <div aria-hidden="false" id="blockmob"></div>
# <script type="text/javascript">
#     var dominios = {"1":{"id-dominio":"1","chave":"saude","label":"sa\u00fade","descricao":"Refere-se \u00e0 sa\u00fade e bem-estar das crian\u00e7as e suas m\u00e3es e \u00e0 habilidade do cuidador em prover sa\u00fade  adequada. ","baixo":"54","medio":"63"},"2":{"id-dominio":"2","chave":"nutricao","label":"nutri\u00e7\u00e3o","descricao":"Refere-se \u00e0 nutri\u00e7\u00e3o da crian\u00e7a e \u00e0 habilidade do cuidador em prover nutri\u00e7\u00e3o adequada. ","baixo":"22","medio":"28"},"3":{"id-dominio":"3","chave":"cuidado","label":"cuidado responsivo","descricao":"Refere-se \u00e0 capacidade dos pais ou cuidadores de perceber, entender e responder aos sinais de seus filhos de maneira oportuna e apropriada. ","baixo":"0","medio":"58"},"4":{"id-dominio":"4","chave":"aprendizagem","label":"aprendizagem inicial","descricao":"Refere-se a oportunidades para a crian\u00e7a interagir com pessoas, locais ou objetos em seu ambiente. ","baixo":"62","medio":"75"},"5":{"id-dominio":"5","chave":"seguranca","label":"seguran\u00e7a e prote\u00e7\u00e3o","descricao":"Refere-se \u00e0 oferta de ambientes seguros e protegidos para crian\u00e7as e suas fam\u00edlias. ","baixo":"20","medio":"25"}};
#     var mun = ["Coronel Barros-RS","Umburatiba-MG","Novo Horizonte-SC","S\u00e3o Sebasti\u00e3o do Anta-MG","Monjolos-MG","Senador Modestino Gon\u00e7alves-MG","Cedro do Abaet\u00e9-MG","Quissam\u00e3-RJ","Bela Vista da Caroba-PR","Entre Folhas-MG","Santa Mercedes-SP","Guarani d'Oeste-SP","Uruguaiana-RS","Paineiras-MG","Dores\u00f3polis-MG","Santa B\u00e1rbara do Leste-MG","Cotipor\u00e3-RS","Itaja\u00ed-SC","Cap\u00e3o Bonito do Sul-RS","Presidente Kennedy-TO","Jaupaci-GO","Limeira do Oeste-MG","Presidente Kubitschek-MG","Marat\u00e1-RS","\u00c1gua Comprida-MG","Alto Capara\u00f3-MG","Brasil\u00e2ndia do Tocantins-TO","Francisc\u00f3polis-MG","Ponto Chique-MG","Cedral-SP","Tigrinhos-SC","Pato Bragado-PR","C\u00f3rrego Fundo-MG","Fortuna de Minas-MG","Ressaquinha-MG","Dion\u00edsio-MG","Bonfin\u00f3polis de Minas-MG","Cruz\u00edlia-MG","Bra\u00fanas-MG","Gentil-RS","Entre Rios-SC","Bandeira-MG","Orat\u00f3rios-MG","Vit\u00f3ria-ES","Cris\u00f3lita-MG","Serra Negra do Norte-RN","Lindolfo Collor-RS","\u00c1guas Frias-SC","S\u00e3o Jos\u00e9 do Herval-RS","Ara\u00e7a\u00ed-MG","Balbinos-SP","Guap\u00e9-MG","Tombos-MG","Peritiba-SC","Gon\u00e7alves-MG","Brusque-SC","Serranos-MG","S\u00e3o Br\u00e1s do Sua\u00e7u\u00ed-MG","Piranguinho-MG","Paulist\u00e2nia-SP","Virgol\u00e2ndia-MG","Taquaral-SP","Bento Gon\u00e7alves-RS","Chapec\u00f3-SC","Flor do Sert\u00e3o-SC","Pedra Dourada-MG","Toropi-RS","Machacalis-MG","Cafeara-PR","Indiapor\u00e3-SP","Crici\u00fama-SC","Natal\u00e2ndia-MG","Igarat\u00e1-SP","Linha Nova-RS","Ibituruna-MG","S\u00e3o Miguel da Boa Vista-SC","Travesseiro-RS","Gonzaga-MG","Periquito-MG","Carea\u00e7u-MG","Cristiano Otoni-MG","Cachoeira Dourada-MG","Vermelho Novo-MG","Jabor\u00e1-SC","Campo Grande-MS","Rochedo de Minas-MG","Macieira-SC","Malacacheta-MG","Senador Amaral-MG","Frei Lagonegro-MG","Itaipul\u00e2ndia-PR","Aragua\u00edna-TO","Iguatu-PR","Cachoeira da Prata-MG","Godoy Moreira-PR","Turmalina-MG","Diamante do Norte-PR","Ipaba-MG","Ascurra-SC","S\u00e3o Pedro da Serra-RS","Imb\u00e9 de Minas-MG","Pomp\u00e9u-MG","Arroio Trinta-SC","Cabeceira Grande-MG","Espera Feliz-MG","Tio Hugo-RS","Olaria-MG","Tapira-MG","Nova Alian\u00e7a do Iva\u00ed-PR","Jer\u00f4nimo Monteiro-ES","Desterro do Melo-MG","C\u00f4nego Marinho-MG","Santa Cec\u00edlia do Sul-RS","Boa Vista do Sul-RS","Botumirim-MG","Lagoa dos Tr\u00eas Cantos-RS","Iomer\u00ea-SC","Jos\u00e9 Boiteux-SC","Farias Brito-CE","Mato Queimado-RS","Florian\u00f3polis-SC","Nazareno-MG","Itamogi-MG","S\u00e3o Domingos do Sul-RS","Luisburgo-MG","Inha\u00fama-MG","Centen\u00e1rio-RS","Inaj\u00e1-PR","Matel\u00e2ndia-PR","S\u00e3o Pedro de Alc\u00e2ntara-SC","Areia de Bara\u00fanas-PB","Fernandes Pinheiro-PR","Teut\u00f4nia-RS","Arapu\u00e1-MG","S\u00e3o Pedro da Uni\u00e3o-MG","S\u00e3o Bento Abade-MG","Fl\u00f3rida-PR","Comendador Gomes-MG","S\u00e3o Jo\u00e3o da Mata-MG","Itati-RS","Matutina-MG","Coxilha-RS","Candeias-MG","Dores do Turvo-MG","Perobal-PR","Rio Doce-MG","Serra Azul de Minas-MG","Ipanema-MG","Palotina-PR","Ribeir\u00e3o Preto-SP","Leme do Prado-MG","Israel\u00e2ndia-GO","Joan\u00e9sia-MG","S\u00e3o Bentinho-PB","Engenheiro Caldas-MG","Quartel Geral-MG","Tocos do Moji-MG","Serran\u00f3polis do Igua\u00e7u-PR","Sete Lagoas-MG","Pedras Altas-RS","Belo Horizonte-MG","Fagundes Varela-RS","Faxinalzinho-RS","Anhembi-SP","Dom Silv\u00e9rio-MG","Dois Lajeados-RS","Marechal Floriano-ES","Reserva do Caba\u00e7al-MT","Ouro Preto-MG","Pinhais-PR","Carvalhos-MG","Barra do Jacar\u00e9-PR","Augusto de Lima-MG","Coronel Martins-SC","Tr\u00eas Fronteiras-SP","Senador Firmino-MG","Sebasti\u00e3o Leal-PI","Ja\u00fa do Tocantins-TO","Vanini-RS","Aracruz-ES","Po\u00e7o das Antas-RS","Santa B\u00e1rbara do Tug\u00fario-MG","Manhumirim-MG","Bras\u00edlia-DF","Florestal-MG","Coimbra-MG","Can\u00e1polis-MG","Lagoa-PB","Mari\u00f3polis-PR","Arroio do Tigre-RS","Tupirama-TO","Arco-\u00cdris-SP","S\u00e3o Jo\u00e3o do Pol\u00easine-RS","Venda Nova do Imigrante-ES","Passa Sete-RS", ...
#     var home_url = 'https://www.imapi.org/';
#
#     var lang ="pt";
# </script>
# <script src="https://www.imapi.org/build/script.js?v=10"></script>
# </body>
# </html>

# %%
labels = []
values = []
dims = []

# %%
for d in soup.find_all('article', attrs={'class':'dimensao-sticky'}):
    for d1 in d.find_all('div', attrs={'class':'col-xs-3'}):
        label = d1.find('p', attrs={'class':'label'})
        dado = d1.find('p', attrs={'class':'dado'})
        print('Label: ', label.text)
        print('Dado: ', dado.text)
        print('------')
# Out:
# Label:  Região
# Dado:  Sudeste
# ------
# Label:  Porte da cidade
# Dado:  Grande porte
# ------
# Label:  Habitantes
# Dado:  696.382
# ------
# Label:  Nascimentos ao ano/ 1000 habitantes
# Dado:  10.320
# ------

# %%
for d in soup.find_all('g'):
    if d.has_attr('data-nota'):
        print('Label: ', d['data-titulo'])
        print('Valor', d['data-nota'])
# Out:
# Label:  saúde
# Valor 46
# Label:  nutrição
# Valor 45
# Label:  cuidado responsivo
# Valor 0
# Label:  aprendizagem inicial
# Valor 74
# Label:  segurança e proteção
# Valor 13

# %%
for d in soup.find_all('section', attrs={'class':'row bottom-xs'}):
    for d1 in d.find_all('div', attrs={'class': 'col-xs-4 tl'}):
        dado = d1.find('p', attrs={'class':'dado'})
        print('Dado', dado.text)
        label = d1.find('p', attrs={'class':'label'})
        print('Label:', label.text)
# Out:
# Dado 2.619º lugar de 5.570
# Label: Ranking Brasil

# %%
for s in soup.find_all('section', attrs={'class':'card'}):
    for d in s.find_all('article', attrs={'class':'indicador'}):
        dado = d.find('p', attrs={'class':'dado'})
        print('Dado: ', dado.text)
        
        label = d.find('p', attrs={'class':'label'})
        print('Label', label.text)
        
        municipio = d.find('div', attrs={'class':'local ativo'})
        if municipio != None and municipio.has_attr('data-nota'):
            valor = municipio['data-nota']
            print('Valor:', valor)
        else:
            valor = 'N/A'
            print(valor)
            print('--------')
# Out:
# Dado:  Início adequado do pré-natal
# Label Percentual de gestantes que iniciaram o pré-natal com 12 semanas ou menos
# Valor: 85,63
# Dado:  Consultas de pré-natal
# Label Percentual de gestantes com 6 ou mais consultas de pré‐natal
# Valor: 75,62
# Dado:  Gravidez na adolescência
# Label Percentual  de gravidez na adolescência
# Valor: 13,38
# Dado:  Cesáreas
# Label Percentual de cesáreas
# Valor: 56,61
# Dado:  Prematuridade
# Label Percentual de crianças nascidas com menos de 37 semanas completas de gestação
# Valor: 13,30
# Dado:  Baixo peso ao nascer
# Label Percentual de nascidos vivos com menos de 2500g
# Valor: 9,62
# Dado:  Sífilis Congênita
# Label Casos confirmados e notificados de sífilis congênita para cada 10.000 crianças  menores de 5 anos
# Valor: 14,40
# Dado:  Visitas domiciliares nos primeiros 10 dias de vida
# Label Percentual de equipes da atenção básica que participaram do PMAQ 2º ciclo e fizeram visitas domiciliares nos primeiros 10 dias de vida
# Valor: 40,00
# Dado:  Cobertura de imunização
# Label Percentual de crianças que receberam o primeiro reforço da DTP
# Valor: 76,79
# Dado:  Cobertura da Atenção Básica de Saúde
# Label Percentual da população coberta pela Atenção Básica
# Valor: 48,00
# Dado:  Internação por pneumonia ou gastroenterites
# Label Percentual  de internações de crianças menores de 5 anos por pneumonia ou gastroenterites
# Valor: 0,23
# Dado:  Mortalidade materna
# Label Mortes de mulheres por causas relacionadas à gravidez, parto ou puerpério para cada 100.000 nascidos vivos
# Valor: 77,54
# Dado:  Mortalidade na Infância
# Label Óbitos de crianças menores de 5 anos para 1000 nascidos vivos
# Valor: 14,64
# Dado:  Óbitos evitáveis em menores de 1 ano
# Label Óbitos evitáveis em crianças menores de um ano para cada 1000 nascidos vivos
# Valor: 13,47
# Dado:  Cobertura de informação sobre estado nutricional
# Label Percentual de crianças menores de 5 anos com pelo menos um registro de informação sobre estado nutricional  no SISVAN
# Valor: 11,13
# Dado:  Cobertura de informação sobre consumo alimentar
# Label Percentual de crianças menores de 5 anos com pelo menos um registro de informação sobre consumo alimentar  no SISVAN
# Valor: 0,00
# Dado:  Insegurança Alimentar Domiciliar Grave
# Label Percentual de insegurança alimentar grave
# Valor: 1,99
# Dado:  Estratégia Amamenta e Alimenta Brasil
# Label Indicador composto por realização de oficina de trabalho e/ou formação de tutores e/ou certificação da unidade básica de saúde
# Valor: 0,67
# Dado:  Visitas do Programa Criança Feliz
# Label Percentual de índivíduos visitados em relação a meta pactuada
# Valor: 0,00
# Dado:  Cobertura de creche e pré-escola
# Label Percentual de matrículas em creche e pré-escola
# Valor: 67,85
# Dado:  Número de alunos por profissional em creches
# Label Número de alunos por profissional em creches
# Valor: 4,00
# Dado:  Número de alunos por profissional em pré-escolas
# Label Número de alunos por profissional em pré-escolas
# Valor: 14,00
# Dado:  Docentes qualificados em creches
# Label Percentual de docentes com curso superior em creches
# Valor: 67,70
# Dado:  Docentes qualificados em pré-escolas
# Label Percentual de docentes com curso superior em  pré-escolas
# Valor: 79,80
# Dado:  Recursos educacionais em creches
# Label Média de recursos educacionais  em creches
# Valor: 1,26
# Dado:  Recursos educacionais em pré-escolas
# Label Média de recursos educacionais  em pré-escolas
# Valor: 1,52
# Dado:  Notificação de violência contra criança
# Label Casos notificados de  violência para cada 1000  crianças menores de 5 anos
# Valor: 0,54
# Dado:  Notificação de violência contra mulher
# Label Casos notificados de violência  para cada 1000  mulheres em idade fértil
# Valor: 0,53
# Dado:  Cobertura do Programa Bolsa Família
# Label Percentual de famílias beneficiárias do Programa Bolsa Família entre as famílias inscritas no Cadastro Único e que têm crianças menores de 5 anos.
# Valor: 61,04
# Dado:  Poluição do ar
# Label Estimativa da concentração diária de PM2,5 (ug/m3)
# Valor: 15,93
# Dado:  Homicídios
# Label Taxa de homicídio estimada por  100 mil habitantes
# Valor: 18,80
